# %%
# Out:
# 0.2.66

# %% [markdown]
# ### Top 6 Stocks with the highest Market Cap:

# %%
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\strus\AppData\Local\Temp\ipykernel_20912\721150108.py:6: SyntaxWarning: invalid escape sequence '\D'
#   "BOA": "C:\\Users\\strus\Downloads\\BOA.csv",

# %%
# Out:
# IAM ['date', 'price', 'open ', 'high', 'low', 'vol', 'change']
# ATW ['date', 'price', 'open', 'high', 'low', 'vol', 'change']
# BCP ['date', 'price', 'open', 'high', 'low', 'vol', 'change']
# TQA ['date ', 'price', 'open', 'high', 'low', 'vol', 'change']
# BOA ['date', 'price', 'open', 'high', 'low', 'vol', 'change']
# MNG ['date', 'price', 'open', 'high', 'low', 'vol', 'change']

# %% [markdown]
# ## Stocks Daily Returns

# %%
# Out:
#             IAM_price  ATW_price  BCP_price  TQA_price  BOA_price  MNG_price
# date
# 2015-01-06  -0.002174   0.000000   0.014184   0.014031  -0.016032   0.000000
# 2015-01-07   0.016122   0.014539   0.011655   0.000000   0.013743   0.025934
# 2015-01-08   0.008576   0.008885   0.036636   0.000233   0.009411  -0.020222
# 2015-01-09   0.016156   0.022727   0.004668   0.015229  -0.000462   0.000000
# 2015-01-12   0.012552   0.010278   0.013274   0.030459  -0.004110   0.000000
# ...               ...        ...        ...        ...        ...        ...
# 2025-11-27   0.026719   0.005479   0.000000   0.000000   0.000000   0.000000
# 2025-11-28  -0.018771  -0.003406  -0.007143   0.000000  -0.000444   0.000000
# 2025-12-01  -0.009565  -0.015721   0.003597   0.000000  -0.008448   0.000000
# 2025-12-02   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2025-12-03   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
# [2714 rows x 6 columns]
# ...

# %%
# Out:
#             IAM_price  ATW_price  BCP_price  TQA_price  BOA_price  MNG_price
# date
# 2015-01-06  -0.002174   0.000000   0.014184   0.014031  -0.016032   0.000000
# 2015-01-07   0.016122   0.014539   0.011655   0.000000   0.013743   0.025934
# 2015-01-08   0.008576   0.008885   0.036636   0.000233   0.009411  -0.020222
# 2015-01-09   0.016156   0.022727   0.004668   0.015229  -0.000462   0.000000
# 2015-01-12   0.012552   0.010278   0.013274   0.030459  -0.004110   0.000000
# ...               ...        ...        ...        ...        ...        ...
# 2025-11-27   0.026719   0.005479   0.000000   0.000000   0.000000   0.000000
# 2025-11-28  -0.018771  -0.003406  -0.007143   0.000000  -0.000444   0.000000
# 2025-12-01  -0.009565  -0.015721   0.003597   0.000000  -0.008448   0.000000
# 2025-12-02   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2025-12-03   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
# [2714 rows x 6 columns]
# ...

# %% [markdown]
# ## Covariance Matix:

# %%
# Out:
#            IAM_price  ATW_price  BCP_price  TQA_price  BOA_price  MNG_price
# IAM_price   0.000134   0.000052   0.000049   0.000020   0.000036   0.000018
# ATW_price   0.000052   0.000130   0.000062   0.000021   0.000042   0.000016
# BCP_price   0.000049   0.000062   0.000144   0.000025   0.000049   0.000021
# TQA_price   0.000020   0.000021   0.000025   0.000144   0.000021   0.000015
# BOA_price   0.000036   0.000042   0.000049   0.000021   0.000201   0.000017
# MNG_price   0.000018   0.000016   0.000021   0.000015   0.000017   0.000286

# %% [markdown]
# ## Volatility Returns (30 days period):

# %%
# Out:
#             IAM_price  ATW_price  BCP_price  TQA_price  BOA_price  MNG_price
# date
# 2015-02-16   0.008337   0.011337   0.012020   0.021231   0.014793   0.008195
# 2015-02-17   0.008384   0.011344   0.011899   0.021226   0.014486   0.008195
# 2015-02-18   0.008049   0.011100   0.011786   0.021249   0.014443   0.006732
# 2015-02-19   0.008092   0.011979   0.010261   0.021216   0.014363   0.005505
# 2015-02-20   0.007911   0.011349   0.010251   0.021156   0.014526   0.009306
# ...               ...        ...        ...        ...        ...        ...
# 2025-11-27   0.012909   0.013090   0.021499   0.000000   0.019535   0.000000
# 2025-11-28   0.013418   0.012511   0.021485   0.000000   0.019481   0.000000
# 2025-12-01   0.013125   0.012265   0.021492   0.000000   0.019140   0.000000
# 2025-12-02   0.013085   0.012257   0.021483   0.000000   0.019070   0.000000
# 2025-12-03   0.012870   0.011515   0.020437   0.000000   0.014541   0.000000
#
# [2685 rows x 6 columns]

# %% [markdown]
# ## (Daily) Static Sharpe Ratio : Help us know how much extra return for extra risk

# %%
# Out:
# IAM_price    0.005488
# ATW_price    0.029587
# BCP_price    0.014526
# TQA_price    0.032198
# BOA_price    0.008007
# MNG_price    0.009058
# dtype: float64

# %%
# Out:
# IAM_price    0.087113
# ATW_price    0.469683
# BCP_price    0.230596
# TQA_price    0.511130
# BOA_price    0.127104
# MNG_price    0.143785
# dtype: float64

# %% [markdown]
# ## Stocks Correlation:

# %%
# Out:
#            IAM_price  ATW_price  BCP_price  TQA_price  BOA_price  MNG_price
# IAM_price   1.000000   0.390379   0.352318   0.147450   0.218938   0.091123
# ATW_price   0.390379   1.000000   0.456143   0.153539   0.258394   0.084803
# BCP_price   0.352318   0.456143   1.000000   0.176555   0.287771   0.103821
# TQA_price   0.147450   0.153539   0.176555   1.000000   0.121845   0.074084
# BOA_price   0.218938   0.258394   0.287771   0.121845   1.000000   0.071842
# MNG_price   0.091123   0.084803   0.103821   0.074084   0.071842   1.000000

# %% [markdown]
# ## Close price plotting :

# %%
# Out:
#             IAM_price  ATW_price  BCP_price TQA_price  BOA_price MNG_price
# date
# 2015-01-02     115.00      343.9     211.50    424.05     215.19       964
# 2015-01-06     114.75      343.9     214.50       430     211.74  1,019.00
# 2015-01-07     116.60      348.9     217.00       430     214.65       989
# 2015-01-08     117.60      352.0     224.95     430.1     216.67       969
# 2015-01-09     119.50      360.0     226.00    436.65     216.57  1,018.00

# %% [markdown]
# ## Individual stock returns:

# %% [markdown]
# ## All stocks return:

# %%
# Out:
# C:\Users\strus\AppData\Local\Temp\ipykernel_20912\3843820268.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rendement=prices[price_cols].pct_change().dropna()

# %% [markdown]
# ## Equal weight portfolio return:

# %%
# Out:
# date
# 2015-01-06    0.001668
# 2015-01-07    0.013666
# 2015-01-08    0.007253
# 2015-01-09    0.009720
# 2015-01-12    0.010409
# dtype: float64

# %%
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'> datetime64[ns]
#             IAM_price  ATW_price  BCP_price  TQA_price  BOA_price  MNG_price
# date
# 2015-01-06  -0.002174   0.000000   0.014184   0.014031  -0.016032   0.000000
# 2015-01-07   0.016122   0.014539   0.011655   0.000000   0.013743   0.025934
# 2015-01-08   0.008576   0.008885   0.036636   0.000233   0.009411  -0.020222
# 2015-01-09   0.016156   0.022727   0.004668   0.015229  -0.000462   0.000000
# 2015-01-12   0.012552   0.010278   0.013274   0.030459  -0.004110   0.000000
# date
# 2015-01-06    0.001668
# 2015-01-07    0.013666
# 2015-01-08    0.007253
# 2015-01-09    0.009720
# 2015-01-12    0.010409
# dtype: float64

# %% [markdown]
# ## MASI20 Benchmark:

# %%
# Out:
#                price    return
# date
# 2015-01-06   9651.78  0.000891
# 2015-01-07   9750.30  0.010207
# 2015-01-08   9803.87  0.005494
# 2015-01-09   9993.19  0.019311
# 2015-01-12  10026.79  0.003362
# ...              ...       ...
# 2025-11-25  18382.71  0.002462
# 2025-11-26  18535.59  0.008317
# 2025-11-27  18640.63  0.005667
# 2025-11-28  18603.59 -0.001987
# 2025-12-01  18434.92 -0.009067
#
# [2711 rows x 2 columns]

# %% [markdown]
# ## Equity Curve : Equal Weight vs MASI20

# %% [markdown]
# ## Portfolio Mu & sigma calculation:

# %%
# Out:
# [-0.20606969  0.59559006 -0.01109658  0.56332242 -0.01741319  0.07566698]
# ['IAM_price', 'ATW_price', 'BCP_price', 'TQA_price', 'BOA_price', 'MNG_price']

# %% [markdown]
# ## Annualized covariance for the choosen stocks:

# %%
# Out:
#            IAM_price  ATW_price  BCP_price  TQA_price  BOA_price  MNG_price
# IAM_price   0.033805   0.012993   0.012350   0.005162   0.009064   0.004496
# ATW_price   0.012993   0.032767   0.015742   0.005291   0.010532   0.004119
# BCP_price   0.012350   0.015742   0.036346   0.006408   0.012353   0.005311
# TQA_price   0.005162   0.005291   0.006408   0.036248   0.005223   0.003785
# BOA_price   0.009064   0.010532   0.012353   0.005223   0.050699   0.004341
# MNG_price   0.004496   0.004119   0.005311   0.003785   0.004341   0.072008

# %% [markdown]
# ## Ranking: Top riskiest vs Top profitable:

# %%
# Out:
#            mu_annual  sigma_annual
# MNG_price   0.038584      0.268344
# BOA_price   0.028619      0.225165
# BCP_price   0.043962      0.190647
# TQA_price   0.097314      0.190390
# IAM_price   0.016017      0.183862
# ATW_price   0.085020      0.181016
#            mu_annual  sigma_annual
# TQA_price   0.097314      0.190390
# ATW_price   0.085020      0.181016
# BCP_price   0.043962      0.190647
# MNG_price   0.038584      0.268344
# BOA_price   0.028619      0.225165
# IAM_price   0.016017      0.183862

# %% [markdown]
# # Efficient frontier WITH THE POSSIBILITY OF SHORT SELLING THE MOROCCAN STOCKS:

# %%
# Out:
# Tangency portfolio weights:
# IAM_price   -0.206070
# ATW_price    0.595590
# BCP_price   -0.011097
# TQA_price    0.563322
# BOA_price   -0.017413
# MNG_price    0.075667
# dtype: float64

# %%
# Out:
# IAM_price   -0.206070
# ATW_price    0.595590
# BCP_price   -0.011097
# TQA_price    0.563322
# BOA_price   -0.017413
# MNG_price    0.075667
# dtype: float64

# %% [markdown]
# ## Efficient Frontier LONG-ONLY STOCKS :

# %% [markdown]
# ## Portfolio building:
# ### For this case we will use the INDIVIDUAL SHARPE as a criteria, first, followed by an EQUAL-WEIGHT approach, followed by SHARPE-MAX, then finally a HYBRID approach:

# %%
# Out:
# IAM_price    0.055507
# ATW_price    0.299273
# BCP_price    0.146932
# TQA_price    0.325682
# BOA_price    0.080988
# MNG_price    0.091617
# dtype: float64
# ['IAM_price', 'ATW_price', 'BCP_price', 'TQA_price', 'BOA_price', 'MNG_price']

# %% [markdown]
# Equal-weight

# %%
# Out:
# [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]
# ['IAM_price', 'ATW_price', 'BCP_price', 'TQA_price', 'BOA_price', 'MNG_price']

# %% [markdown]
# Max-sharpe:

# %%
# Out:
# [1.87851253e-18 4.53703607e-01 0.00000000e+00 4.86150249e-01
#  1.55961968e-17 6.01461433e-02]
# ['IAM_price', 'ATW_price', 'BCP_price', 'TQA_price', 'BOA_price', 'MNG_price']

# %% [markdown]
# Hybrid-approach:

# %%
# Out:
# IAM_price    0.048987
# ATW_price    0.247998
# BCP_price    0.120049
# TQA_price    0.377898
# BOA_price    0.080285
# MNG_price    0.124784
# dtype: float64
# ['IAM_price', 'ATW_price', 'BCP_price', 'TQA_price', 'BOA_price', 'MNG_price']

# %% [markdown]
# ## Pie Chart for the portfolio constitution:

# %% [markdown]
# ## Historical Backtesting of 4 portfolios:

# %% [markdown]
# ### Drawdown chart for the 4 portfolios:

# %% [markdown]
# ### CAGR, Volatility, Sharpe & MaxDD summary for the 4 portfolios:

# %%
# Out:
#                   CAGR       Vol    Sharpe     MaxDD
# A_Sharpe      0.064779  0.119792   0.58831 -0.312838
# B_RiskParity  0.045509  0.117404  0.439389 -0.346542
# C_MaxSharpe   0.081513  0.135473  0.651081 -0.293622
# D_Hybrid       0.06529  0.119729  0.592728 -0.315339
